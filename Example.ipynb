# %% [markdown]
# # KomoriVis

# %%
import komori as km

# Figure size manipulation
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["figure.figsize"] = (20,20)

# %%
_file='test_data/bats.wav'

# %%
recording = km.recording(_file)

# %%
spectrogram = km.spectrogram(recording, n_fft=2048, hop=256)

# %%
spectrogram.plot()
